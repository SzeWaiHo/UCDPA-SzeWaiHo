# %% [markdown]
# # Project - Who will win the LoL 2023 Worlds?

# %% [markdown]
# # Step 0.5 - Graphs

# %%
#install graphviz
# !pip install graphviz
import graphviz

#needed to install the graphviz/bin (executable variables) in both system and Python (Jupyter)
#followed: https://www.youtube.com/watch?v=kOYnlqbZ8K4&t=127s

# %%
#graphviz Guide
#easy example

#create the graph 
g = graphviz.Digraph()

#add a node (shape)
g.node("a",shape = "box")
g.node("b",shape="box")
g.edges(['ab'])

#views as PDF 
#g.view()

#views in notebook
g

# %%
#SOURCE - https://renenyffenegger.ch/notes/tools/Graphviz/examples/index

import graphviz
dot_data = '''
digraph sportsbracket {

    node [fontname="Arial"];

    node_A [shape=record    label="{above|middle}|{right|left}"];
    \

}
'''
graph = graphviz.Source(dot_data)
graph

# %%
#SOURCE - https://marc.info/?l=graphviz-interest&m=120831967907825&w=2
import graphviz
dot_data = '''
digraph sportsbracket {

rankdir=LR
graph [size="11,8.5", fontname="Helvetica", label="NCAA 2008 Men's National \
Championship", splines=false]

node [shape=box, width=2, fontname="Helvetica"]
aa

node [style=invis, width=auto, label=""]
edge [style=invis]

rank=same {ax->aa->ay}

node [style=solid, width=2, fontname="Helvetica"]
edge [style=solid]

aa [label="Kansas"]

baa [label="Kansas"]
bba [label="Memphis"]

caa [label="North Carolina"]
cab [label="Kansas"]
cba [label="Memphis"]
cbb [label="UCLA"]

daa [label="North Carolina"]
dab [label="Louisville"]
dac [label="Kansas"]
dad [label="Davidson"]
dba [label="Memphis"]
dbb [label="Texas"]
dbc [label="UCLA"]
dbd [label="Xavier"]

eaa [label="North Carolina"]
eab [label="Wash. State"]
eac [label="Louisville"]
ead [label="Tennessee"]
eae [label="Kansas"]
eaf [label="Villanova"]
eag [label="Wisconsin"]
eah [label="Davidson"]
eba [label="Memphis"]
ebb [label="Mich. State"]
ebc [label="Stanford"]
ebd [label="Texas"]
ebe [label="UCLA"]
ebf [label="Western Ky."]
ebg [label="Xavier"]
ebh [label="West Virginia"]

faa [label="North Carolina"]
fab [label="Arkansas"]
fac [label="Notre Dame"]
fad [label="Wash. State"]
fae [label="Oklahoma"]
faf [label="Louisville"]
fag [label="Butler"]
fah [label="Tennessee"]
fai [label="Kansas"]
faj [label="UNLV"]
fak [label="Villanova"]
fal [label="Siena"]
fam [label="Kansas State"]
fan [label="Wisconsin"]
fao [label="Davidson"]
fap [label="Georgetown"]
fba [label="Memphis"]
fbb [label="Miss. State"]
fbc [label="Mich. State"]
fbd [label="Pittsburgh"]
fbe [label="Marquette"]
fbf [label="Stanford"]
fbg [label="Miami (Fla.)"]
fbh [label="Texas"]
fbi [label="UCLA"]
fbj [label="Texas A&M"]
fbk [label="Western Ky."]
fbl [label="San Diego"]
fbm [label="Purdue"]
fbn [label="Xavier"]
fbo [label="West Virginia"]
fbp [label="Duke"]

gaa [label="North Carolina"]
gab [label="Mt. St. Mary's"]
gac [label="Indiana"]
gad [label="Arkansas"]
gae [label="Notre Dame"]
gaf [label="George Mason"]
gag [label="Wash. State"]
gah [label="Winthrop"]
gai [label="Oklahoma"]
gaj [label="St. Joseph's"]
gak [label="Louisville"]
gal [label="Boise State"]
gam [label="Butler"]
gan [label="South Alabama"]
gao [label="Tennessee"]
gap [label="American"]
gaq [label="Kansas"]
gar [label="Portland State"]
gas [label="UNLV"]
gat [label="Kent State"]
gau [label="Clemson"]
gav [label="Villanova"]
gaw [label="Vanderbilt"]
gax [label="Siena"]
gay [label="Southern California"]
gaz [label="Kansas State"]
ga1 [label="Wisconsin"]
ga2 [label="CS-Fullerton"]
ga3 [label="Gonzaga"]
ga4 [label="Davidson"]
ga5 [label="Georgetown"]
ga6 [label="UMBC"]
gba [label="Memphis"]
gbb [label="Texas-Arlington"]
gbc [label="Miss. State"]
gbd [label="Oregon"]
gbe [label="Mich. State"]
gbf [label="Temple"]
gbg [label="Pittsburgh"]
gbh [label="Oral Roberts"]
gbi [label="Marquette"]
gbj [label="Kentucky"]
gbk [label="Stanford"]
gbl [label="Cornell"]
gbm [label="Miami (Fla.)"]
gbn [label="St. Mary's"]
gbo [label="Texas"]
gbp [label="Austin Peay"]
gbq [label="UCLA"]
gbr [label="Miss. Valley St."]
gbs [label="BYU"]
gbt [label="Texas A&M"]
gbu [label="Drake"]
gbv [label="Western Ky."]
gbq [label="Connecticut"]
gbx [label="San Diego"]
gby [label="Purdue"]
gbz [label="Baylor"]
gb1 [label="Xavier"]
gb2 [label="Georgia"]
gb3 [label="West Virginia"]
gb4 [label="Arizona"]
gb5 [label="Duke"]
gb6 [label="Belmont"]

baa:e->ax:w

caa:e->baa:w
cab:e->baa:w

daa:e->caa:w
dab:e->caa:w
dac:e->cab:w
dad:e->cab:w

eaa:e->daa:w
eab:e->daa:w
eac:e->dab:w
ead:e->dab:w
eae:e->dac:w
eaf:e->dac:w
eag:e->dad:w
eah:e->dad:w

faa:e->eaa:w
fab:e->eaa:w
fac:e->eab:w
fad:e->eab:w
fae:e->eac:w
faf:e->eac:w
fag:e->ead:w
fah:e->ead:w
fai:e->eae:w
faj:e->eae:w
fak:e->eaf:w
fal:e->eaf:w
fam:e->eag:w
fan:e->eag:w
fao:e->eah:w
fap:e->eah:w

gaa:e->faa:w
gab:e->faa:w
gac:e->fab:w
gad:e->fab:w
gae:e->fac:w
gaf:e->fac:w
gag:e->fad:w
gah:e->fad:w
gai:e->fae:w
gaj:e->fae:w
gak:e->faf:w
gal:e->faf:w
gam:e->fag:w
gan:e->fag:w
gao:e->fah:w
gap:e->fah:w
gaq:e->fai:w
gar:e->fai:w
gas:e->faj:w
gat:e->faj:w
gau:e->fak:w
gav:e->fak:w
gaw:e->fal:w
gax:e->fal:w
gay:e->fam:w
gaz:e->fam:w
ga1:e->fan:w
ga2:e->fan:w
ga3:e->fao:w
ga4:e->fao:w
ga5:e->fap:w
ga6:e->fap:w

edge [dir=back]

ay:e->bba:w

bba:e->cba:w
bba:e->cbb:w

cba:e->dba:w
cba:e->dbb:w
cbb:e->dbc:w
cbb:e->dbd:w

dba:e->eba:w
dba:e->ebb:w
dbb:e->ebc:w
dbb:e->ebd:w
dbc:e->ebe:w
dbc:e->ebf:w
dbd:e->ebg:w
dbd:e->ebh:w

eba:e->fba:w
eba:e->fbb:w
ebb:e->fbc:w
ebb:e->fbd:w
ebc:e->fbe:w
ebc:e->fbf:w
ebd:e->fbg:w
ebd:e->fbh:w
ebe:e->fbi:w
ebe:e->fbj:w
ebf:e->fbk:w
ebf:e->fbl:w
ebg:e->fbm:w
ebg:e->fbn:w
ebh:e->fbo:w
ebh:e->fbp:w

fba:e->gba:w
fba:e->gbb:w
fbb:e->gbc:w
fbb:e->gbd:w
fbc:e->gbe:w
fbc:e->gbf:w
fbd:e->gbg:w
fbd:e->gbh:w
fbe:e->gbi:w
fbe:e->gbj:w
fbf:e->gbk:w
fbf:e->gbl:w
fbg:e->gbm:w
fbg:e->gbn:w
fbh:e->gbo:w
fbh:e->gbp:w
fbi:e->gbq:w
fbi:e->gbr:w
fbj:e->gbs:w
fbj:e->gbt:w
fbk:e->gbu:w
fbk:e->gbv:w
fbl:e->gbw:w
fbl:e->gbx:w
fbm:e->gby:w
fbm:e->gbz:w
fbn:e->gb1:w
fbn:e->gb2:w
fbo:e->gb3:w
fbo:e->gb4:w
fbp:e->gb5:w
fbp:e->gb6:w

edge [style=invis]

rank=same {gaa->gab->gac->gad->gae->gaf->gag->gah->gai->gaj->gak->gal->gam->gan->gao-> \
gap->gaq->gar->gas->gat->gau->gav->gaw->gax->gay->gaz->ga1->ga2->ga3->ga4->ga5->ga6} \
rank=same {gba->gbb->gbc->gbd->gbe->gbf->gbg->gbh->gbi->gbj->gbk->gbl->gbm->gbn->gbo-> \
gbp->gbq->gbr->gbs->gbt->gbu->gbv->gbw->gbx->gby->gbz->gb1->gb2->gb3->gb4->gb5->gb6}

}
'''

graph = graphviz.Source(dot_data)
graph

# %%
#Play-Ins: Brackets

#import graphviz package
import graphviz

#define data
dot_data = '''
digraph sportsbracket {

#direction is downwards
rankdir=LR

#set graph attributes
graph [label="2023 LoL Worlds - Knockout Stage", fontname = "Helvetica", splines=false]

node [shape=box, width=2]

node [style=invis, label="",fontname = "Helvetica"]
edge [style=invis]

rank=same

node [style=solid, fontname = "Helvetica"]
edge [style=solid]


rQ [shape = oval, label = "QUARTERFINALS", fontsize = 20]

r1a [shape = record, label = "{A1|JDG}"]
r1b [shape = record, label = "{B2|RGE}"]
r1c [shape = record, label = "{B1|T1}"]
r1d [shape = record, label = "{A2|RNG}"]
r1e [shape = record, label = "{C1|GEN}"]
r1f [shape = record, label = "{D2|DK}"]
r1g [shape = record, label = "{D1|DRX}"]
r1h [shape = record, label = "{C2|EDG}"]

rS [shape = oval, label = "SEMI-FINALS", fontsize = 20]

r2a [shape = record, label = "{Q1|JDG}"]
r2b [shape = record, label = "{Q2|T1}"]
r2c [shape = record, label = "{Q3|GEN}"]
r2d [shape = record, label = "{Q4|DRX}"]


r3a [shape = record, label = "{F1|T1}"]
r3b [shape = record, label = "{F2|DRX}"]

r4a [shape = record, label = "{WINNER|DRX}"]

r1a:e->r2a:w
r1b:e->r2a:w
r1c:e->r2b:w
r1d:e->r2b:w
r1e:e->r2c:w
r1f:e->r2c:w
r1g:e->r2d:w
r1h:e->r2d:w

r2a:e->r3a:w
r2b:e->r3a:w
r2c:e->r3b:w
r2d:e->r3b:w

r3a:e->r4a:w
r3b:e->r4a:w

}
'''

#create graph
graph = graphviz.Source(dot_data)

#show graph
graph
