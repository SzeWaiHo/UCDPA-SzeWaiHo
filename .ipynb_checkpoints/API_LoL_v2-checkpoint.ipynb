# %%
#https://lol.fandom.com/wiki/Help:Leaguepedia_API
""" 
    This is the website I used to figure out how to query API from Leaguepedia (storing all match statistics)
"""
import mwclient

#This is the LeaguePedia website that stores all match and team statistics
site = mwclient.Site('lol.fandom.com', path='/')


"""
    I searched for a quicker way to iterate for loops because it took too long to run
"""
#https://github.com/tqdm/tqdm 
from tqdm.notebook import tqdm

#pre-set the leagues I want to look at - all those that will qualify to worlds
#leagues=['GPL','IWCQ','WCS','LCS','LEC','LCK','LPL','CBLOL','LCL','LJL','LLA','OPL','PCS','VCS','TCL','LMS','LST','NA LCS','EU LCS','LLN','CLS']
#leagues=['LCS','LEC','LCK','LPL','CBLOL','LJL','LLA','PCS','VCS']
leagues=['LCK']

#create an empty list to store my dataset
results = []

#for loop to create my data base of match stats
for league in tqdm(leagues):
    off=0
    
    #while loop to retrive data thruogh API
    while True:
        #API query
        response = site.api('cargoquery',
                            offset=str(off),
                            
                            limit="500",
                            
                            #retrive tables
                            tables = "ScoreboardGames=SG, ScoreboardPlayers=SP,Tournaments=T, Leagues=L",
                            
                            #retrive fields as columns
                            fields="T.Name=Tournament,\
                                    L.League_Short=League,\
                                    SP.Link,\
                                    SG.DateTime_UTC, SG.Gamelength, SG.Team1, SG.Team2, SG.Team1Score, SG.Team2Score", 
                            
                            #set condition (only include specified leagues)
                            where = 'L.League_Short = "'+league+'"',
                            
                            #similar to vlookup in the web pages
                            join_on = "SG.OverviewPage=T.OverviewPage, T.League = L.League, SP.MatchId=SG.MatchId")
        
        #add to database
        results += response["cargoquery"] 
        
        #speed
        off=off+500
        if(len(response["cargoquery"])<500): break
        

#import pandas as pd
#df_Scoreboard = pd.DataFrame([ a['title'] for a in results ])
#df_Scoreboard = df_Scoreboard.drop("DateTime UTC__precision", axis=1)
#df_Scoreboard.sort_values("DateTime UTC")
#df_Scoreboard.head()
#df_Scoreboard.to_csv("Scoreboard.csv")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import pandas as pd
df_Scoreboard = pd.DataFrame([ a['title'] for a in results ])
df_Scoreboard = df_Scoreboard.drop("DateTime UTC__precision", axis=1)
df_Scoreboard.sort_values("DateTime UTC")
df_Scoreboard.head()
#df_Scoreboard.to_csv("Scoreboard.csv")

# %%
#https://lol.fandom.com/wiki/Help:Leaguepedia_API
""" 
    This is the website I used to figure out how to query API from Leaguepedia (storing all match statistics)
"""
import mwclient

#This is the LeaguePedia website that stores all match and team statistics
site = mwclient.Site('lol.fandom.com', path='/')


"""
    I searched for a quicker way to iterate for loops because it took too long to run
"""
#https://github.com/tqdm/tqdm 
from tqdm.notebook import tqdm

#pre-set the leagues I want to look at - all those that will qualify to worlds
#leagues=['LCS','LEC','LCK','LPL','CBLOL','LJL','LLA','PCS','VCS']
leagues=['LCK']

#create an empty list to store my dataset
results = []

#for loop to create my data base of match stats
for league in tqdm(leagues):
    off=0
    
    #while loop to retrive data thruogh API
    while True:
        #API query
        response = site.api('cargoquery',
                            offset=str(off),
                            
                            limit="max",
                            
                            #retrive tables
                            tables = "Teams=T, Players=P",
                            
                            #retrive fields as columns
                            fields="P.Team=Team, P.ID=ID, P.Nationality, P.Country,P.Birthdate,\
                                    T.Region=Region, T.Short", 
                            
                            #set condition 
                            #where = 'T.Name = P.Team',
                            
                            #similar to vlookup in the web pages
                            join_on = "T.Name = P.Team")
        
        #add to database
        results += response["cargoquery"] 
        
        #speed
        off=off+500
        if(len(response["cargoquery"])<500): break

        
        
import pandas as pd
df_Players = pd.DataFrame([ a['title'] for a in results ])

#drop birthdate precision
df_Players = df_Players.drop("Birthdate__precision", axis=1)

df_Players.head()
#df_Players.to_csv("Players.csv")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#    Team    ID Nationality Country Birthdate   Region Short
# 0  None  None        None    None      None  Vietnam    TF
# 1  None  None        None    None      None    Korea  DK.A
# 2  None  None        None    None      None     EMEA   YTR
# 3  None  None        None    None      None   Europe  RIFT
# 4  None  None        None    None      None   Europe  NERO

# %%
df_stats = df_Scoreboard.merge(df_Players, left_on = 'Team1', right_on = 'Team', how = 'left')
df_stats.head()
df_stats.to_csv("Merged.csv")

# %%
#############################################################################################################################
#############################################################################################################################
#############################################################################################################################
#############################################################################################################################

# %% [markdown]
# # Imported all leagues scoreboard games data

# %%
""" 
    This is the website I used to figure out how to query API from Leaguepedia (storing all match statistics)
"""
#https://lol.fandom.com/wiki/Help:Leaguepedia_API
import mwclient

#This is the LeaguePedia website that stores all match and team statistics
site = mwclient.Site('lol.fandom.com', path='/')


"""
    I searched for a quicker way to iterate for loops because it took too long to run
"""
#https://github.com/tqdm/tqdm 
from tqdm.notebook import tqdm

#pre-set the leagues I want to look at - all those that will qualify to worlds
leagues=['GPL','IWCQ','WCS','LCS','LEC','LCK','LPL','CBLOL','LCL','LJL','LLA','OPL','PCS','VCS','TCL','LMS','LST','NA LCS','EU LCS','LLN','CLS']


#create an empty list to store my dataset
results = []

#for loop to create my data base of match stats
for league in tqdm(leagues):
    off=0
    
    #while loop to retrive data thruogh API
    while True:
        #API query
        response = site.api('cargoquery',
                            offset=str(off),
                            
                            limit="max",
                            
                            #retrive tables
                            tables = "ScoreboardGames=SG,Tournaments=T, Leagues=L",
                            
                            #retrive fields as columns
                            fields="T.Name=Tournament,\
                                    L.League_Short=League,\
                                    SG.DateTime_UTC=Date, SG.Gamelength, SG.Team1, SG.Team2, SG.Team1Score, SG.Team2Score,SG.WinTeam", 
                            
                            #set condition (only include specified leagues)
                            where = 'L.League_Short = "'+league+'"',
                            
                            #similar to vlookup in the web pages
                            join_on = "SG.OverviewPage=T.OverviewPage, T.League = L.League")
        
        #add to database
        results += response["cargoquery"] 
        
        #speed
        off=off+500
        if(len(response["cargoquery"])<500): break
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[8], line 31
#      29 while True:
#      30     #API query
# ---> 31     response = site.api('cargoquery',
#      32                         offset=str(off),
#      33
#      34                         limit="max",
#      35
#      36                         #retrive tables
#      37                         tables = "ScoreboardGames=SG,Tournaments=T, Leagues=L, MatchSchedule=M",
#      38
#      39                         #retrive fields as columns
#      40                         fields="T.Name=Tournament,\
#      41                                 L.League_Short=League,\
#      42                                 SG.DateTime_UTC=Date, SG.Gamelength, SG.Team1, SG.Team2, SG.Team1Score, SG.Team2Score,SG.WinTeam,M.Tab",
#      43
#      44                         #set condition (only include specified leagues)
#      45                         where = 'L.League_Short = "'+league+'"',
#      46
#      47                         #similar to vlookup in the web pages
#      48                         join_on = "M.OverviewPage =T.OverviewPage, SG.OverviewPage=T.OverviewPage, T.League = L.League")
#      50     #add to database
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\mwclient\client.py:285, in Site.api(self, action, http_method, *args, **kwargs)
#     284 while True:
# --> 285     info = self.raw_api(action, http_method, **kwargs)
#     286     if not info:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\mwclient\client.py:437, in Site.raw_api(self, action, http_method, *args, **kwargs)
#     436 data = self._query_string(*args, **kwargs)
# --> 437 res = self.raw_call('api', data, retry_on_error=retry_on_error,
#     438                     http_method=http_method)
#     440 try:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\mwclient\client.py:399, in Site.raw_call(self, script, data, files, retry_on_error, http_method)
#     397     args['data'] = data
# --> 399 stream = self.connection.request(http_method, url, **args)
#     401 if stream.headers.get('x-database-lag'):
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\interactiveshell.py:2057, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2056     else:
# -> 2057         stb = self.InteractiveTB.structured_traceback(
#    2058             etype, value, tb, tb_offset=tb_offset
#    2059         )
#    2061 except Exception:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\ultratb.py:1118, in AutoFormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1117     self.tb = tb
# -> 1118 return FormattedTB.structured_traceback(
#    1119     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\ultratb.py:1012, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1010 if mode in self.verbose_modes:
#    1011     # Verbose modes need a full traceback
# -> 1012     return VerboseTB.structured_traceback(
#    1013         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1014     )
#    1015 elif mode == 'Minimal':
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\ultratb.py:865, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#     864 """Return a nice text document describing the traceback."""
# --> 865 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#     866                                                        tb_offset)
#     868 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\ultratb.py:799, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     797 head = self.prepare_header(etype, self.long_header)
#     798 records = (
# --> 799     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     800 )
#     802 frames = []
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\ultratb.py:854, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#     849 options = stack_data.Options(
#     850     before=before,
#     851     after=after,
#     852     pygments_formatter=formatter,
#     853 )
# --> 854 return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\stack_data\core.py:597, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     595     return frame.f_code, lineno
# --> 597 yield from collapse_repeated(
#     598     stack,
#     599     mapper=mapper,
#     600     collapser=RepeatedFrames,
#     601     key=_frame_key,
#     602 )
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\stack_data\utils.py:83, in collapse_repeated(lst, collapser, mapper, key)
#      82 if is_highlighted:
# ---> 83     yield from map(mapper, original_group)
#      84 else:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\stack_data\core.py:587, in FrameInfo.stack_data.<locals>.mapper(f)
#     586 def mapper(f):
# --> 587     return cls(f, options)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\stack_data\core.py:551, in FrameInfo.__init__(self, frame_or_tb, options)
#     546 def __init__(
#     547         self,
#     548         frame_or_tb: Union[FrameType, TracebackType],
#     549         options: Optional[Options] = None,
#     550 ):
# --> 551     self.executing = Source.executing(frame_or_tb)
#     552     frame, self.lineno = frame_and_lineno(frame_or_tb)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\executing\executing.py:359, in Source.executing(cls, frame_or_tb)
#     358 node = stmts = decorator = None
# --> 359 source = cls.for_frame(frame)
#     360 tree = source.tree
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\executing\executing.py:277, in Source.for_frame(cls, frame, use_cache)
#     274 """
#     275 Returns the `Source` object corresponding to the file the frame is executing in.
#     276 """
# --> 277 return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\executing\executing.py:306, in Source.for_filename(cls, filename, module_globals, use_cache)
#     304     lines = get_lines()
# --> 306 return cls._for_filename_and_lines(filename, tuple(lines))
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\executing\executing.py:317, in Source._for_filename_and_lines(cls, filename, lines)
#     315     pass
# --> 317 result = source_cache[(filename, lines)] = cls(filename, lines)
#     318 return result
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\executing\executing.py:268, in Source.__init__(self, filename, lines)
#     267 visitor = QualnameVisitor()
# --> 268 visitor.visit(self.tree)
#     269 self._qualnames = visitor.qualnames
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:371, in NodeVisitor.visit(self, node)
#     370 visitor = getattr(self, method, self.generic_visit)
# --> 371 return visitor(node)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:379, in NodeVisitor.generic_visit(self, node)
#     378         if isinstance(item, AST):
# --> 379             self.visit(item)
#     380 elif isinstance(value, AST):
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:371, in NodeVisitor.visit(self, node)
#     370 visitor = getattr(self, method, self.generic_visit)
# --> 371 return visitor(node)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:381, in NodeVisitor.generic_visit(self, node)
#     380 elif isinstance(value, AST):
# --> 381     self.visit(value)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:371, in NodeVisitor.visit(self, node)
#     370 visitor = getattr(self, method, self.generic_visit)
# --> 371 return visitor(node)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:379, in NodeVisitor.generic_visit(self, node)
#     378         if isinstance(item, AST):
# --> 379             self.visit(item)
#     380 elif isinstance(value, AST):
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:371, in NodeVisitor.visit(self, node)
#     370 visitor = getattr(self, method, self.generic_visit)
# --> 371 return visitor(node)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:402, in NodeVisitor.visit_Constant(self, node)
#     401         return visitor(node)
# --> 402 return self.generic_visit(node)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:375, in NodeVisitor.generic_visit(self, node)
#     374 """Called if no explicit visitor function exists for a node."""
# --> 375 for field, value in iter_fields(node):
#     376     if isinstance(value, list):
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\ast.py:216, in iter_fields(node)
#     215 for field in node._fields:
# --> 216     try:
#     217         yield field, getattr(node, field)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\interactiveshell.py:2078, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2075         self._showtraceback(etype, value, stb)
#    2077 except KeyboardInterrupt:
# -> 2078     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\IPython\core\interactiveshell.py:2014, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2009 """
#    2010 Return as a string (ending with a newline) the exception that
#    2011 just occurred, without any traceback.
#    2012 """
#    2013 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2014 msg = traceback.format_exception_only(etype, value)
#    2015 return ''.join(msg)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\traceback.py:140, in format_exception_only(etype, value)
#     124 def format_exception_only(etype, value):
#     125     """Format the exception part of a traceback.
#     126
#     127     The arguments are the exception type and value such as given by
#    (...)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\traceback.py:524, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     522     self.msg = exc_value.msg
#     523 if lookup_lines:
# --> 524     self._load_lines()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\traceback.py:536, in TracebackException._load_lines(self)
#     534     frame.line
#     535 if self.__context__:
# --> 536     self.__context__._load_lines()
#     537 if self.__cause__:
#     538     self.__cause__._load_lines()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\traceback.py:534, in TracebackException._load_lines(self)
#     532 """Private API. force all lines in the stack to be loaded."""
#     533 for frame in self.stack:
# --> 534     frame.line
#     535 if self.__context__:
#     536     self.__context__._load_lines()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\traceback.py:288, in FrameSummary.line(self)
#     285 @property
#     286 def line(self):
#     287     if self._line is None:
# --> 288         self._line = linecache.getline(self.filename, self.lineno).strip()
#     289     return self._line
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\linecache.py:16, in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\linecache.py:47, in getlines(filename, module_globals)
#      44         return cache[filename][2]
#      46 try:
# ---> 47     return updatecache(filename, module_globals)
#      48 except MemoryError:
#      49     clearcache()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except OSError:
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\tokenize.py:392, in open(filename)
#     388 def open(filename):
#     389     """Open a file in read only mode using the encoding detected by
#     390     detect_encoding().
#     391     """
# --> 392     buffer = _builtin_open(filename, 'rb')
#     393     try:
#     394         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:

# %% [markdown]
# # Convert to Panda DataFrame and Clean Data

# %%
#import pandas package
import pandas as pd

#convert to dataframe from dictionary
df_Scoreboard = pd.DataFrame([ a['title'] for a in results ])
#df_Scoreboard = pd.read_csv("Scoreboard.csv")

#drop unused column
df_Scoreboard = df_Scoreboard.drop("Date__precision", axis=1)

#sort by date
df_Scoreboard.sort_values(by = "Date",inplace=True)

#split date and time
df_Scoreboard["Date"] = pd.to_datetime(df_Scoreboard["Date"])
df_Scoreboard["Year"]= df_Scoreboard["Date"].dt.year

#convert Team 1 & 2 score as integers
df_Scoreboard = df_Scoreboard.astype({'Team1Score':'int','Team2Score':'int'})

#preview first few rows
df_Scoreboard.head()

#save as csv
df_Scoreboard.to_csv("Scoreboard.csv")

# %% [markdown]
# # Get Worlds 2011 - 2022 Winners

# %%
""" 
    This is the website I used to figure out how to query API from Leaguepedia (storing all match statistics)
"""
#https://lol.fandom.com/wiki/Help:Leaguepedia_API
import mwclient

#This is the LeaguePedia website that stores all match and team statistics
site = mwclient.Site('lol.fandom.com', path='/')


"""
    I searched for a quicker way to iterate for loops because it took too long to run
"""
#https://github.com/tqdm/tqdm 
from tqdm.notebook import tqdm

#pre-set the leagues I want to look at - all those that will qualify to worlds
leagues=['WCS']


#create an empty list to store my dataset
results = []

#for loop to create my data base of match stats
for league in tqdm(leagues):
    off=0
    
    #while loop to retrive data thruogh API
    while True:
        #API query
        response = site.api('cargoquery',
                            offset=str(off),
                            
                            limit="max",
                            
                            #retrive tables
                            tables = "ScoreboardGames=SG,Tournaments=T, Leagues=L, MatchSchedule=M",
                            
                            #retrive fields as columns
                            fields="T.Name=Tournament,\
                                    L.League_Short=League,\
                                    SG.DateTime_UTC=Date, SG.Gamelength, SG.Team1, SG.Team2, SG.Team1Score, SG.Team2Score,SG.WinTeam, M.Tab", 
                            
                            #set condition (only include specified leagues)
                            where = 'L.League_Short = "'+league+'"',
                            
                            #similar to vlookup in the web pages
                            join_on = "SG.OverviewPage=T.OverviewPage, T.League = L.League, M.OverviewPage=T.OverviewPage")
        
        #add to database
        results += response["cargoquery"] 
        
        #speed
        off=off+500
        if(len(response["cargoquery"])<500): break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#import pandas package
import pandas as pd

#convert to dataframe from dictionary
df_Scoreboard_Worlds = pd.DataFrame([ a['title'] for a in results ])
#df_Scoreboard = pd.read_csv("Scoreboard.csv")

#drop unused column
df_Scoreboard_Worlds = df_Scoreboard_Worlds.drop("Date__precision", axis=1)

#sort by date
df_Scoreboard_Worlds.sort_values(by = "Date",inplace=True)

#split date and time
df_Scoreboard_Worlds["Date"] = pd.to_datetime(df_Scoreboard_Worlds["Date"])
df_Scoreboard_Worlds["Year"]= df_Scoreboard_Worlds["Date"].dt.year

#convert Team 1 & 2 score as integers
df_Scoreboard_Worlds = df_Scoreboard_Worlds.astype({'Team1Score':'int','Team2Score':'int'})

#preview first few rows
df_Scoreboard_Worlds.head()

#save as csv
df_Scoreboard_Worlds.to_csv("Scoreboard_Worlds.csv")

# %%
#I want to get the winners of all the Worlds Championships only
#I can't filter from 'WCS' league because it randomly includes regional finals
#But the tournaments that begin with "Worlds" can be identified
df_Scoreboard_Worlds2 = df_Scoreboard_Worlds[df_Scoreboard_Worlds["Tournament"].str.startswith("Worlds")]

df_Scoreboard_Worlds2.head()
#df_Scoreboard_Worlds2.to_csv("Scoreboard_Worlds2.csv")
# Out:
#             Tournament League                Date Gamelength  \
# 49542  Worlds Season 1    WCS 2011-06-18 08:30:00      45:09
# 49562  Worlds Season 1    WCS 2011-06-18 08:30:00      45:09
# 49561  Worlds Season 1    WCS 2011-06-18 08:30:00      45:09
# 49560  Worlds Season 1    WCS 2011-06-18 08:30:00      45:09
# 49559  Worlds Season 1    WCS 2011-06-18 08:30:00      45:09
#
#                        Team1       Team2  Team1Score  Team2Score     WinTeam  \
# 49542  against All authority  Epik Gamer           0           1  Epik Gamer
# 49562  against All authority  Epik Gamer           0           1  Epik Gamer
# 49561  against All authority  Epik Gamer           0           1  Epik Gamer
# 49560  against All authority  Epik Gamer           0           1  Epik Gamer
# 49559  against All authority  Epik Gamer           0           1  Epik Gamer
#
#                Tab  Year
# 49542  Group Stage  2011
# 49562       Finals  2011
# 49561      Round 3  2011
# 49560      Round 3  2011
# 49559      Round 2  2011

# %%
#define function to get winner of each match
def get_Winner(year):
    df_Scoreboard_Worlds2[df_Scoreboard_Worlds2["Year"]==year]
    return

# %%
#who won the most matches in Worlds Championship
#most_wins = df_Scoreboard_Worlds2["WinTeam"].value_counts()

import seaborn as sns

top_10_teams = (df_Scoreboard_Worlds2['WinTeam'].value_counts()).iloc[:10]

#create bar chart of top 10 teams
top_10_teams.plot(kind='bar',title='Top 10 Teams')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Teams'}>

# %%
#create function to get winner of each season/worlds 
def get_winner(year):
    finals = df_Scoreboard_Worlds2[df_Scoreboard_Worlds2["Tab"]=="Finals"]
    finals_year = finals[finals["Year"]==year]
    winner = finals_year["WinTeam"].value_counts( ).idxmax()
    return winner

get_winner(2020)

#create dictionary for Worlds Winners
years = [i for i in range(2011,2023)]

winners = []
for i in range(2011,2023):
    winners.append(get_winner(i))

dict_worlds_winners = {}
for i in range(len(keys)):
    dict_worlds_winners[years[i]] = winners[i]

#create dataframe from dictionary
df_worlds_winners = pd.DataFrame(data = [dict_worlds_winners])
df_worlds_winners = df_worlds_winners.transpose()
df_worlds_winners.reset_index(inplace=True)
df_worlds_winners.columns = ["Year","Winner"]
df_worlds_winners
# Out:
#     Year           Winner
# 0   2011           Fnatic
# 1   2012      Azubu Frost
# 2   2013    SK Telecom T1
# 3   2014    Samsung White
# 4   2015    SK Telecom T1
# 5   2016    SK Telecom T1
# 6   2017   Samsung Galaxy
# 7   2018  Invictus Gaming
# 8   2019  FunPlus Phoenix
# 9   2020    DAMWON Gaming
# 10  2021          DWG KIA
# 11  2022              DRX

# %% [markdown]
# # Imported all teams region data

# %%
import mwclient
site = mwclient.Site('lol.fandom.com', path='/')

from tqdm.notebook import tqdm

#pre-set the leagues I want to look at - all those that will qualify to worlds
leagues=['GPL','IWCQ','WCS','LCS','LEC','LCK','LPL','CBLOL','LCL','LJL','LLA','OPL','PCS','VCS','TCL','LMS','LST','NA LCS','EU LCS','LLN','CLS']


#create an empty list to store my dataset
results = []

#for loop to create my data base of match stats
for league in tqdm(leagues):
    off=0
    
    #while loop to retrive data thruogh API
    while True:
        #API query
        response = site.api("cargoquery",
                            offset=str(off),
                            
                            limit="max",
                            
                            #retrive tables
                            tables = "Teams=T",
                            
                            #retrive fields as columns
                            fields="T.Name=Team, T.Region=Region, T.Short=Team_abbr")
                            
        #add to database
        results += response["cargoquery"] 
        
        #speed
        off=off+500
        if(len(response["cargoquery"])<500): break
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# # Convert to Panda DataFrame and Clean Data

# %%
import pandas as pd
df_TeamRegion = pd.DataFrame([ a['title'] for a in results ])
#df_TeamRegion = pd.read_csv("TeamRegion.csv", index_col = 0)


df_TeamRegion = df_TeamRegion.dropna()
df_TeamRegion = df_TeamRegion.drop_duplicates(subset="Team")
df_TeamRegion.head()

#df_TeamRegion.to_csv("TeamRegion.csv")
# Out:
#                             Team         Region Team_abbr
# 9                      00 Nation         Europe       00N
# 10                  00 Prospects         Europe       00P
# 11                1 Trick Ponies  North America       1TP
# 12  1. Berliner Esport-Club e.V.         Europe      BESC
# 13                   100 Thieves  North America       100

# %%
df_worlds_winners2 = df_worlds_winners.merge(df_TeamRegion, left_on = "Winner", right_on = "Team", how = "left")
df_worlds_winners2 = df_worlds_winners2.drop(columns="Team")
df_worlds_winners2
# Out:
#     Year           Winner Region Team_abbr
# 0   2011           Fnatic   EMEA       FNC
# 1   2012      Azubu Frost  Korea       AZF
# 2   2013    SK Telecom T1  Korea       SKT
# 3   2014    Samsung White  Korea       SSW
# 4   2015    SK Telecom T1  Korea       SKT
# 5   2016    SK Telecom T1  Korea       SKT
# 6   2017   Samsung Galaxy  Korea       SSG
# 7   2018  Invictus Gaming  China        iG
# 8   2019  FunPlus Phoenix  China       FPX
# 9   2020    DAMWON Gaming    NaN       NaN
# 10  2021          DWG KIA    NaN       NaN
# 11  2022              DRX  Korea       DRX

# %%
#DAMWON Gaming and DWG KIA both renamed - They are the same team...
#need to add this detail in df
df_TeamRegion2 = {"Team":"DAMWON Gaming",
                  "Region":"Korea",
                  "Team_abbr":"DK"}

df_TeamRegion3 = {"Team":"DWG KIA",
                  "Region":"Korea",
                  "Team_abbr":"DK"}

df_TeamRegion = df_TeamRegion.append(df_TeamRegion2, ignore_index=True)
df_TeamRegion = df_TeamRegion.append(df_TeamRegion3, ignore_index=True)
df_TeamRegion
# Out:
#                               Team         Region Team_abbr
# 0                        00 Nation         Europe       00N
# 1                     00 Prospects         Europe       00P
# 2                   1 Trick Ponies  North America       1TP
# 3     1. Berliner Esport-Club e.V.         Europe      BESC
# 4                      100 Thieves  North America       100
# ...                            ...            ...       ...
# 2846          Zwan Gaming Colombia  Latin America     ZWN.C
# 2847            Zwan Gaming Mexico  Latin America     ZWN.M
# 2848                Zylant Esports  Latin America       ZLT
# 2849                 DAMWON Gaming          Korea        DK
# 2850                       DWG KIA          Korea        DK
#
# [2851 rows x 3 columns]

# %%
#repeat after adding the missing teams
df_worlds_winners2 = df_worlds_winners.merge(df_TeamRegion, left_on = "Winner", right_on = "Team", how = "left")
df_worlds_winners2 = df_worlds_winners2.drop(columns="Team")
df_worlds_winners2
# Out:
#     Year           Winner Region Team_abbr
# 0   2011           Fnatic   EMEA       FNC
# 1   2012      Azubu Frost  Korea       AZF
# 2   2013    SK Telecom T1  Korea       SKT
# 3   2014    Samsung White  Korea       SSW
# 4   2015    SK Telecom T1  Korea       SKT
# 5   2016    SK Telecom T1  Korea       SKT
# 6   2017   Samsung Galaxy  Korea       SSG
# 7   2018  Invictus Gaming  China        iG
# 8   2019  FunPlus Phoenix  China       FPX
# 9   2020    DAMWON Gaming  Korea        DK
# 10  2021          DWG KIA  Korea        DK
# 11  2022              DRX  Korea       DRX

# %%
#Plot frequencies of team winners
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax = df_worlds_winners2["Team_abbr"].value_counts().plot(kind='bar',
                                    figsize=(10,5),
                                    title="LoL Worlds Winners - Teams")
ax.set_xlabel("Teams")
ax.set_ylabel("Frequency")

import numpy as np
plt.yticks(np.arange(0, 4, 1))
# Out:
# ([<matplotlib.axis.YTick at 0x249109883a0>,
#   <matplotlib.axis.YTick at 0x2491097ad00>,
#   <matplotlib.axis.YTick at 0x2491ace5ee0>,
#   <matplotlib.axis.YTick at 0x24911324b80>],
#  [Text(0, 0, '0'), Text(0, 1, '1'), Text(0, 2, '2'), Text(0, 3, '3')])

# %%
#Plot frequencies of region winners
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax = df_worlds_winners2["Region"].value_counts().plot(kind='bar',
                                    figsize=(10,5),
                                    title="LoL Worlds Winners - Regions")
ax.set_xlabel("Regions")
ax.set_ylabel("Frequency")

import numpy as np
plt.yticks(np.arange(0, 10, 1))
# Out:
# ([<matplotlib.axis.YTick at 0x249119f2850>,
#   <matplotlib.axis.YTick at 0x249119f21f0>,
#   <matplotlib.axis.YTick at 0x24911a9c8e0>,
#   <matplotlib.axis.YTick at 0x24911ac6d90>,
#   <matplotlib.axis.YTick at 0x24911ac6b50>,
#   <matplotlib.axis.YTick at 0x24911accee0>,
#   <matplotlib.axis.YTick at 0x24911acc3d0>,
#   <matplotlib.axis.YTick at 0x24911ab9bb0>,
#   <matplotlib.axis.YTick at 0x24911b9a790>,
#   <matplotlib.axis.YTick at 0x24911b9af70>],
#  [Text(0, 0, '0'),
#   Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9')])

# %%
#dictionary to match regions
dict_regions = {
    'Africa':'EMEA',
    'Brazil':'BR',
    'China':'CN',
    'CIS':'INT',
    'EMEA':'EMEA',
    'Europe':'EMEA',
    'International':'INT',
    'Japan':'JP',
    'Korea':'KR',
    'LAN':'INT',
    'LAS':'INT',
    'Latin America':'LAT',
    'LMS':'INT',
    'MENA':'INT',
    'North America':'NA',
    'Oceania':'PCS',
    'PCS':'PCS',
    'SEA':'PCS',
    'Turkey':'EMEA',
    'Vietnam':'VN'
}

#define function to get region code from dictionary
def get_region_code(region):
    return dict_regions[region]


#add column for region code
for index,row in df_TeamRegion["Region"].items():
    df_TeamRegion["Region_code"] = df_TeamRegion["Region"].apply(get_region_code)
    
df_regions.head()
#df_regions.to_csv("TeamRegionCode.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 31
#      28 get_region_code(df_TeamRegion["Region"][2])
#      30 for index,row in df_TeamRegion["Region"].items():
# ---> 31     df_TeamRegion["Region_code"] = df_TeamRegion["Region"].apply(get_region_code)
#      34 #df_regions = pd.DataFrame(dict_regions)
#      35 #df_regions.reset_index()
#      36 df_regions.head()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 25, in get_region_code(region)
#       1 #dictionary to match regions
#       2 dict_regions = {
#       3     'Africa':'EMEA',
#       4     'Brazil':'BR',
#    (...)
#      22     'Vietnam':'VN'
#      23 }
# ---> 25 def get_region_code(region):
#      26     return dict_regions[region]
#      28 get_region_code(df_TeamRegion["Region"][2])
#
# KeyboardInterrupt:

# %%
#############################################################################################################################

# %%
df_team1 = df_Scoreboard.merge(df_TeamRegion, left_on = 'Team1', right_on = 'Team', how = 'left')
df_team1.rename(columns = {'Team':'Team1','Region':'Region_T1','Team_abbr':'T1_code'}, inplace = True)
df_team1.head()
#df_team1.to_csv("Merged Team 1.csv")
# Out:
#    Unnamed: 0       Tournament League                 Date Gamelength  \
# 0        2127  Worlds Season 1    WCS  2011-06-18 08:30:00      45:09
# 1        2127  Worlds Season 1    WCS  2011-06-18 08:30:00      45:09
# 2        2127  Worlds Season 1    WCS  2011-06-18 08:30:00      45:09
# 3        2127  Worlds Season 1    WCS  2011-06-18 08:30:00      45:09
# 4        2127  Worlds Season 1    WCS  2011-06-18 08:30:00      45:09
#
#                    Team1       Team2  Team1Score  Team2Score     WinTeam  \
# 0  against All authority  Epik Gamer           0           1  Epik Gamer
# 1  against All authority  Epik Gamer           0           1  Epik Gamer
# 2  against All authority  Epik Gamer           0           1  Epik Gamer
# 3  against All authority  Epik Gamer           0           1  Epik Gamer
# 4  against All authority  Epik Gamer           0           1  Epik Gamer
#
#    Year                  Team1 Region_T1 T1_code
# 0  2011  against All authority    Europe     aAa
# 1  2011  against All authority    Europe     aAa
# 2  2011  against All authority    Europe     aAa
# 3  2011  against All authority    Europe     aAa
# 4  2011  against All authority    Europe     aAa

# %%
#create dictionary to match start and end of league season
#season dates found on Leaguepedia
dict_match_season = {
    2023:{'Start':'2022-11-11 00:00:00','End':'2023-10-01 00:00:00'},
    2022:{'Start':'2021-11-11 00:00:00','End':'2022-10-01 00:00:00'},  
    2021:{'Start':'2020-11-11 00:00:00','End':'2021-10-01 00:00:00'},  
    2020:{'Start':'2019-11-11 00:00:00','End':'2020-10-01 00:00:00'},  
    2019:{'Start':'2018-11-04 00:00:00','End':'2019-10-09 00:00:00'},
    2018:{'Start':'2017-11-05 00:00:00','End':'2018-10-08 00:00:00'},
    2017:{'Start':'2016-10-30 00:00:00','End':'2017-09-30 00:00:00'},
    2016:{'Start':'2015-10-30 00:00:00','End':'2016-09-30 00:00:00'},
    2015:{'Start':'2014-10-30 00:00:00','End':'2015-09-30 00:00:00'},
    2014:{'Start':'2013-10-30 00:00:00','End':'2014-09-30 00:00:00'},
    2013:{'Start':'2012-10-30 00:00:00','End':'2013-09-30 00:00:00'},
    2012:{'Start':'2011-10-30 00:00:00','End':'2012-09-30 00:00:00'},
}

# %%
df_team1_2 = df_Scoreboard.merge(df_TeamRegion, left_on = 'Team1', right_on = 'Team', how = 'left')#\
                            #.merge(df_TeamRegion,left_on = 'Team2', right_on = 'Team', how = 'left', suffixes=("_T1","_T2"))
#df_team1_2.head()
df_team1_2.to_csv("Merged Teams.csv")

# %%
#create dictionary for all match stats within the season 
dict_match_data_per_season=dict()
for date in dict_match_season:
    dict_match_data_per_season[date] = df_Scoreboard[
        (df_Scoreboard.Date>dict_match_season[date]['Start'])&
        (df_Scoreboard.Date<dict_match_season[date]['End'])]

# %%
#get match data per season
df_match_data_per_season = pd.DataFrame(dict_match_data_per_season[2015])
df_match_data_per_season.head()
# Out:
#                          Tournament  League                Date Gamelength  \
# 27662  NA LCS 2015 Spring Expansion  NA LCS 2014-11-15 20:07:00      36:28
# 27663  NA LCS 2015 Spring Expansion  NA LCS 2014-11-15 20:30:00      24:00
# 27664  NA LCS 2015 Spring Expansion  NA LCS 2014-11-15 21:34:00      35:31
# 27665  NA LCS 2015 Spring Expansion  NA LCS 2014-11-15 22:53:00      38:18
# 27666  NA LCS 2015 Spring Expansion  NA LCS 2014-11-15 23:45:00      23:08
#
#                  Team1            Team2  Team1Score  Team2Score      WinTeam  \
# 27662      Team LoLPro  Fission Esports           1           0  Team LoLPro
# 27663       Team Coast      Call Gaming           1           0   Team Coast
# 27664      Call Gaming       Team Coast           0           2   Team Coast
# 27665  Fission Esports      Team LoLPro           0           2  Team LoLPro
# 27666            Enemy      Noble Truth           1           0        Enemy
#
#        Year
# 27662  2014
# 27663  2014
# 27664  2014
# 27665  2014
# 27666  2014

# %%
#get leagues - without duplicates
dict_match_data_per_season[2022]["League"].unique()
# Out:
# array(['VCS', 'LPL', 'LCK', 'LEC', 'LCS', 'TCL', 'CBLOL', 'LLA', 'LJL',
#        'PCS', 'LCL', 'WCS'], dtype=object)

# %%
#because LoL changed the league names, I create a dictionary to match the old and new league names
#alias = {
dict_league_names = {
    'GPL': 'PCS', 
    'NA LCS': 'LCS', 
    'EU LCS': 'LEC', 
    'LPL': 'LPL', 
    'TCL': 'PCS', 
    'LJL': 'LJL', 
    'CBLOL': 'CBLOL',
    'LMS': 'PCS', 
    'OPL': 'OPL', 
    'CLS': 'LLA', 
    'LCK': 'LCK', 
    'LCL': 'LCL', 
    'LLN': 'LLA', 
    'VCS': 'PCS', 
    'LEC': 'LEC',
    'LLA': 'LLA', 
    'LCS': 'LCS', 
    'PCS': 'PCS',
    'LST': 'PCS'
}
list_regions = list(set([dict_league_names[name] for name in dict_league_names]))

# %%
#create a dictionary for Worlds Stats 
dict_Worlds_data=dict()

#create a dictionary for Groups Data
dict_groups_data=dict()

#for all years in stats 2011 - 2022:
for year in range (2011, 2023):
    
    response = site.api('cargoquery',
                        limit="max",
                        tables = "MatchSchedule=M",
                        fields="M.Team1Final=Team1, M.Team2Final=Team2, M.Team1Score, M.Team2Score, M.Tab",
                        where = 'M.OverviewPage = "'+str(year)+' Season World Championship/Main Event"')
    
    #create dictionary for LoL Worlds Championship match stats
    dict_Worlds_data[year] = pd.DataFrame ( [ a['title'] for a in response['cargoquery'] ] )
    
    response = site.api('cargoquery',
                        limit="max",
                        tables = "TournamentGroups=T",
                        fields="T.Team, T.GroupName",
                        where = 'T.OverviewPage = "'+str(year)+' Season World Championship/Main Event"')
    
    #create dictionary for Groups Data
    dict_groups_data[year] = pd.DataFrame ( [ a['title'] for a in response['cargoquery'] ] )

# %%
dict_Worlds_data
# Out:
# {2011: Empty DataFrame
#  Columns: []
#  Index: [],
#  2012: Empty DataFrame
#  Columns: []
#  Index: [],
#  2013: Empty DataFrame
#  Columns: []
#  Index: [],
#  2014: Empty DataFrame
#  Columns: []
#  Index: [],
#  2015: Empty DataFrame
#  Columns: []
#  Index: [],
#  2016: Empty DataFrame
#  Columns: []
#  Index: [],
#  2017:                   Team1                Team2 Team1Score Team2Score  \
#  0      ahq eSports Club               Cloud9          0          1
#  1      ahq eSports Club        EDward Gaming          0          1
#  2      ahq eSports Club        SK Telecom T1          1          0
#  3                Cloud9     ahq eSports Club          1          0
#  4                Cloud9        EDward Gaming          1          0
#  5                Cloud9        SK Telecom T1          0          1
#  6         EDward Gaming     ahq eSports Club          0          1
#  7         EDward Gaming               Cloud9          1          0
#  8         EDward Gaming        SK Telecom T1          0          1
#  9    Fenerbahçe Esports           G2 Esports          0          1
#  10   Fenerbahçe Esports  Royal Never Give Up          0          1
#  11   Fenerbahçe Esports       Samsung Galaxy          0          1
#  12         Flash Wolves       Misfits Gaming          0          1
#  13         Flash Wolves              Team WE          0          1
#  14         Flash Wolves                  TSM          0          1
#  15               Fnatic     GIGABYTE Marines          0          1
#  16               Fnatic            Immortals          1          0
#  17               Fnatic            Immortals          1          0
#  18               Fnatic       Longzhu Gaming          0          1
#  19           G2 Esports   Fenerbahçe Esports          1          0
#  20           G2 Esports  Royal Never Give Up          1          0
#  21           G2 Esports       Samsung Galaxy          0          1
#  22     GIGABYTE Marines               Fnatic          0          1
#  23     GIGABYTE Marines               Fnatic          0          1
#  24     GIGABYTE Marines            Immortals          0          1
#  25     GIGABYTE Marines       Longzhu Gaming          0          1
#  26            Immortals               Fnatic          1          0
#  27            Immortals     GIGABYTE Marines          0          1
#  28            Immortals       Longzhu Gaming          0          1
#  29       Longzhu Gaming               Fnatic          1          0
#  30       Longzhu Gaming     GIGABYTE Marines          1          0
#  31       Longzhu Gaming            Immortals          1          0
#  32       Longzhu Gaming       Samsung Galaxy          0          3
#  33       Misfits Gaming         Flash Wolves          1          0
#  34       Misfits Gaming              Team WE          0          1
#  35       Misfits Gaming                  TSM          1          0
#  36       Misfits Gaming                  TSM          1          0
#  37  Royal Never Give Up   Fenerbahçe Esports          1          0
#  38  Royal Never Give Up               Fnatic          3          1
#  39  Royal Never Give Up           G2 Esports          1          0
#  40  Royal Never Give Up       Samsung Galaxy          1          0
#  41       Samsung Galaxy   Fenerbahçe Esports          1          0
#  42       Samsung Galaxy           G2 Esports          1          0
#  43       Samsung Galaxy  Royal Never Give Up          0          1
#  44       Samsung Galaxy              Team WE          3          1
#  45        SK Telecom T1     ahq eSports Club          1          0
#  46        SK Telecom T1               Cloud9          1          0
#  47        SK Telecom T1        EDward Gaming          1          0
#  48        SK Telecom T1       Misfits Gaming          3          2
#  49        SK Telecom T1  Royal Never Give Up          3          2
#  50        SK Telecom T1       Samsung Galaxy          0          3
#  51              Team WE               Cloud9          3          2
#  52              Team WE         Flash Wolves          1          0
#  53              Team WE       Misfits Gaming          1          0
#  54              Team WE                  TSM          1          0
#  55                  TSM         Flash Wolves          0          1
#  56                  TSM       Misfits Gaming          1          0
#  57                  TSM              Team WE          1          0
#
#                Tab
#  0           Day 2
#  1           Day 8
#  2           Day 8
#  3           Day 8
#  4           Day 3
#  5           Day 8
#  6           Day 1
#  7           Day 8
#  8           Day 2
#  9           Day 6
#  10          Day 6
#  11          Day 4
#  12          Day 3
#  13          Day 7
#  14          Day 2
#  15          Day 1
#  16          Day 5
#  17          Day 5
#  18          Day 4
#  19          Day 3
#  20          Day 6
#  21          Day 1
#  22          Day 5
#  23          Day 5
#  24          Day 4
#  25          Day 5
#  26          Day 2
#  27          Day 5
#  28          Day 5
#  29          Day 5
#  30          Day 2
#  31          Day 1
#  32  Quarterfinals
#  33          Day 7
#  34          Day 7
#  35          Day 4
#  36          Day 7
#  37          Day 1
#  38  Quarterfinals
#  39          Day 4
#  40          Day 6
#  41          Day 6
#  42          Day 6
#  43          Day 3
#  44     Semifinals
#  45          Day 3
#  46          Day 1
#  47          Day 8
#  48  Quarterfinals
#  49     Semifinals
#  50         Finals
#  51  Quarterfinals
#  52          Day 4
#  53          Day 2
#  54          Day 7
#  55          Day 7
#  56          Day 7
#  57          Day 3  ,
#  2018:                   Team1                Team2 Team1Score Team2Score  \
#  0           100 Thieves               Fnatic          0          1
#  1           100 Thieves                G-Rex          1          0
#  2           100 Thieves      Invictus Gaming          0          1
#  3        Afreeca Freecs               Cloud9          0          3
#  4        Afreeca Freecs         Flash Wolves          1          0
#  5        Afreeca Freecs           G2 Esports          0          1
#  6        Afreeca Freecs     Phong Vũ Buffalo          1          0
#  7                Cloud9               Fnatic          0          3
#  8                Cloud9                Gen.G          0          1
#  9                Cloud9  Royal Never Give Up          1          0
#  10               Cloud9        Team Vitality          1          0
#  11        EDward Gaming           KT Rolster          1          0
#  12        EDward Gaming             MAD Team          1          0
#  13        EDward Gaming          Team Liquid          0          1
#  14         Flash Wolves       Afreeca Freecs          1          0
#  15         Flash Wolves           G2 Esports          0          1
#  16         Flash Wolves           G2 Esports          1          0
#  17         Flash Wolves     Phong Vũ Buffalo          0          1
#  18               Fnatic          100 Thieves          1          0
#  19               Fnatic        EDward Gaming          3          1
#  20               Fnatic                G-Rex          1          0
#  21               Fnatic      Invictus Gaming          0          1
#  22               Fnatic      Invictus Gaming          0          3
#  23               Fnatic      Invictus Gaming          1          0
#  24                G-Rex          100 Thieves          0          1
#  25                G-Rex               Fnatic          0          1
#  26                G-Rex      Invictus Gaming          0          1
#  27           G2 Esports       Afreeca Freecs          0          1
#  28           G2 Esports         Flash Wolves          1          0
#  29           G2 Esports      Invictus Gaming          0          3
#  30           G2 Esports     Phong Vũ Buffalo          1          0
#  31                Gen.G               Cloud9          0          1
#  32                Gen.G  Royal Never Give Up          0          1
#  33                Gen.G        Team Vitality          0          1
#  34      Invictus Gaming          100 Thieves          1          0
#  35      Invictus Gaming               Fnatic          0          1
#  36      Invictus Gaming                G-Rex          1          0
#  37           KT Rolster        EDward Gaming          1          0
#  38           KT Rolster      Invictus Gaming          2          3
#  39           KT Rolster             MAD Team          1          0
#  40           KT Rolster          Team Liquid          1          0
#  41             MAD Team        EDward Gaming          0          1
#  42             MAD Team           KT Rolster          0          1
#  43             MAD Team          Team Liquid          0          1
#  44     Phong Vũ Buffalo       Afreeca Freecs          0          1
#  45     Phong Vũ Buffalo         Flash Wolves          0          1
#  46     Phong Vũ Buffalo           G2 Esports          1          0
#  47  Royal Never Give Up               Cloud9          1          0
#  48  Royal Never Give Up               Cloud9          1          0
#  49  Royal Never Give Up           G2 Esports          2          3
#  50  Royal Never Give Up                Gen.G          1          0
#  51  Royal Never Give Up        Team Vitality          1          0
#  52          Team Liquid        EDward Gaming          0          1
#  53          Team Liquid           KT Rolster          0          1
#  54          Team Liquid             MAD Team          1          0
#  55        Team Vitality               Cloud9          0          1
#  56        Team Vitality                Gen.G          1          0
#  57        Team Vitality  Royal Never Give Up          1          0
#
#                Tab
#  0           Day 2
#  1           Day 3
#  2           Day 8
#  3   Quarterfinals
#  4           Day 6
#  5           Day 1
#  6           Day 4
#  7      Semifinals
#  8           Day 3
#  9           Day 5
#  10          Day 5
#  11          Day 7
#  12          Day 1
#  13          Day 7
#  14          Day 2
#  15    Tiebreakers
#  16          Day 6
#  17          Day 6
#  18          Day 8
#  19  Quarterfinals
#  20          Day 8
#  21          Day 3
#  22         Finals
#  23    Tiebreakers
#  24          Day 8
#  25          Day 4
#  26          Day 8
#  27          Day 6
#  28          Day 4
#  29     Semifinals
#  30          Day 6
#  31          Day 5
#  32          Day 2
#  33          Day 1
#  34          Day 4
#  35          Day 8
#  36          Day 2
#  37          Day 4
#  38  Quarterfinals
#  39          Day 7
#  40          Day 1
#  41          Day 7
#  42          Day 3
#  43          Day 7
#  44          Day 6
#  45          Day 1
#  46          Day 2
#  47          Day 1
#  48    Tiebreakers
#  49  Quarterfinals
#  50          Day 5
#  51          Day 3
#  52          Day 3
#  53          Day 7
#  54          Day 4
#  55          Day 2
#  56          Day 5
#  57          Day 5  ,
#  2019:                     Team1                  Team2 Team1Score Team2Score  \
#  0        ahq eSports Club          DAMWON Gaming          0          1
#  1        ahq eSports Club        Invictus Gaming          0          1
#  2        ahq eSports Club            Team Liquid          0          1
#  3                  Cloud9             G2 Esports          0          1
#  4                  Cloud9  Griffin (Korean Team)          0          1
#  5                  Cloud9     Hong Kong Attitude          1          0
#  6           Clutch Gaming                 Fnatic          0          1
#  7           Clutch Gaming    Royal Never Give Up          0          1
#  8           Clutch Gaming          SK Telecom T1          0          1
#  9           DAMWON Gaming       ahq eSports Club          1          0
#  10          DAMWON Gaming             G2 Esports          1          3
#  11          DAMWON Gaming        Invictus Gaming          1          0
#  12          DAMWON Gaming            Team Liquid          0          1
#  13                 Fnatic          Clutch Gaming          1          0
#  14                 Fnatic    Royal Never Give Up          1          0
#  15                 Fnatic          SK Telecom T1          0          1
#  16        FunPlus Phoenix                 Fnatic          3          1
#  17        FunPlus Phoenix            GAM Esports          1          0
#  18        FunPlus Phoenix                 J Team          1          0
#  19        FunPlus Phoenix                 Splyce          1          0
#  20        FunPlus Phoenix                 Splyce          1          0
#  21             G2 Esports                 Cloud9          1          0
#  22             G2 Esports        FunPlus Phoenix          0          3
#  23             G2 Esports  Griffin (Korean Team)          0          1
#  24             G2 Esports  Griffin (Korean Team)          0          1
#  25             G2 Esports     Hong Kong Attitude          1          0
#  26             G2 Esports          SK Telecom T1          3          1
#  27            GAM Esports        FunPlus Phoenix          0          1
#  28            GAM Esports                 J Team          0          1
#  29            GAM Esports                 Splyce          0          1
#  30  Griffin (Korean Team)                 Cloud9          1          0
#  31  Griffin (Korean Team)             G2 Esports          0          1
#  32  Griffin (Korean Team)     Hong Kong Attitude          1          0
#  33  Griffin (Korean Team)        Invictus Gaming          1          3
#  34     Hong Kong Attitude                 Cloud9          0          1
#  35     Hong Kong Attitude             G2 Esports          0          1
#  36     Hong Kong Attitude  Griffin (Korean Team)          0          1
#  37        Invictus Gaming       ahq eSports Club          1          0
#  38        Invictus Gaming          DAMWON Gaming          0          1
#  39        Invictus Gaming        FunPlus Phoenix          1          3
#  40        Invictus Gaming            Team Liquid          1          0
#  41                 J Team        FunPlus Phoenix          1          0
#  42                 J Team            GAM Esports          0          1
#  43                 J Team                 Splyce          0          1
#  44    Royal Never Give Up          Clutch Gaming          1          0
#  45    Royal Never Give Up                 Fnatic          1          0
#  46    Royal Never Give Up          SK Telecom T1          0          1
#  47          SK Telecom T1          Clutch Gaming          1          0
#  48          SK Telecom T1                 Fnatic          0          1
#  49          SK Telecom T1    Royal Never Give Up          1          0
#  50          SK Telecom T1                 Splyce          3          1
#  51                 Splyce        FunPlus Phoenix          1          0
#  52                 Splyce            GAM Esports          1          0
#  53                 Splyce                 J Team          0          1
#  54            Team Liquid       ahq eSports Club          1          0
#  55            Team Liquid          DAMWON Gaming          0          1
#  56            Team Liquid        Invictus Gaming          0          1
#
#                Tab
#  0           Day 2
#  1           Day 8
#  2           Day 3
#  3           Day 6
#  4           Day 4
#  5           Day 2
#  6           Day 7
#  7           Day 7
#  8           Day 4
#  9           Day 8
#  10  Quarterfinals
#  11          Day 8
#  12          Day 1
#  13          Day 2
#  14          Day 7
#  15          Day 1
#  16  Quarterfinals
#  17          Day 4
#  18          Day 5
#  19          Day 3
#  20    Tiebreakers
#  21          Day 3
#  22         Finals
#  23          Day 6
#  24    Tiebreakers
#  25          Day 6
#  26     Semifinals
#  27          Day 5
#  28          Day 5
#  29          Day 1
#  30          Day 6
#  31          Day 2
#  32          Day 3
#  33  Quarterfinals
#  34          Day 6
#  35          Day 4
#  36          Day 6
#  37          Day 1
#  38          Day 3
#  39     Semifinals
#  40          Day 8
#  41          Day 1
#  42          Day 3
#  43          Day 5
#  44          Day 1
#  45          Day 4
#  46          Day 7
#  47          Day 7
#  48          Day 7
#  49          Day 2
#  50  Quarterfinals
#  51          Day 5
#  52          Day 5
#  53          Day 4
#  54          Day 8
#  55          Day 8
#  56          Day 2  ,
#  2020:                     Team1                  Team2 Team1Score Team2Score  \
#  0           DAMWON Gaming                    DRX          3          0
#  1           DAMWON Gaming              JD Gaming          1          0
#  2           DAMWON Gaming              PSG Talon          1          0
#  3           DAMWON Gaming  Rogue (European Team)          1          0
#  4                     DRX               FlyQuest          1          0
#  5                     DRX            Top Esports          0          1
#  6                     DRX   Unicorns of Love.CIS          1          0
#  7                FlyQuest                    DRX          0          1
#  8                FlyQuest            Top Esports          0          1
#  9                FlyQuest   Unicorns of Love.CIS          1          0
#  10                 Fnatic                  Gen.G          1          0
#  11                 Fnatic             LGD Gaming          1          0
#  12                 Fnatic                    TSM          1          0
#  13             G2 Esports          DAMWON Gaming          1          3
#  14             G2 Esports          Machi Esports          1          0
#  15             G2 Esports                 Suning          0          1
#  16             G2 Esports                 Suning          1          0
#  17             G2 Esports            Team Liquid          0          1
#  18                  Gen.G                 Fnatic          1          0
#  19                  Gen.G             G2 Esports          0          3
#  20                  Gen.G             LGD Gaming          1          0
#  21                  Gen.G                    TSM          1          0
#  22              JD Gaming          DAMWON Gaming          1          0
#  23              JD Gaming              PSG Talon          0          1
#  24              JD Gaming  Rogue (European Team)          1          0
#  25             LGD Gaming                 Fnatic          1          0
#  26             LGD Gaming                  Gen.G          0          1
#  27             LGD Gaming                    TSM          1          0
#  28          Machi Esports             G2 Esports          0          1
#  29          Machi Esports                 Suning          0          1
#  30          Machi Esports            Team Liquid          1          0
#  31              PSG Talon          DAMWON Gaming          0          1
#  32              PSG Talon              JD Gaming          0          1
#  33              PSG Talon  Rogue (European Team)          1          0
#  34  Rogue (European Team)          DAMWON Gaming          0          1
#  35  Rogue (European Team)              JD Gaming          0          1
#  36  Rogue (European Team)              PSG Talon          1          0
#  37                 Suning          DAMWON Gaming          1          3
#  38                 Suning             G2 Esports          1          0
#  39                 Suning              JD Gaming          3          1
#  40                 Suning          Machi Esports          1          0
#  41                 Suning            Team Liquid          0          1
#  42            Team Liquid             G2 Esports          0          1
#  43            Team Liquid          Machi Esports          1          0
#  44            Team Liquid                 Suning          0          1
#  45            Top Esports                    DRX          1          0
#  46            Top Esports               FlyQuest          0          1
#  47            Top Esports                 Fnatic          3          2
#  48            Top Esports                 Suning          1          3
#  49            Top Esports   Unicorns of Love.CIS          1          0
#  50                    TSM                 Fnatic          0          1
#  51                    TSM                  Gen.G          0          1
#  52                    TSM             LGD Gaming          0          1
#  53   Unicorns of Love.CIS                    DRX          0          1
#  54   Unicorns of Love.CIS               FlyQuest          0          1
#  55   Unicorns of Love.CIS            Top Esports          0          1
#
#                Tab
#  0   Quarterfinals
#  1           Day 1
#  2           Day 3
#  3           Day 6
#  4           Day 4
#  5           Day 8
#  6           Day 8
#  7           Day 8
#  8           Day 1
#  9           Day 3
#  10          Day 4
#  11          Day 7
#  12          Day 7
#  13     Semifinals
#  14          Day 5
#  15    Tiebreakers
#  16          Day 2
#  17          Day 4
#  18          Day 7
#  19  Quarterfinals
#  20          Day 1
#  21          Day 2
#  22          Day 6
#  23          Day 6
#  24          Day 3
#  25          Day 2
#  26          Day 7
#  27          Day 7
#  28          Day 3
#  29          Day 5
#  30          Day 2
#  31          Day 6
#  32          Day 2
#  33          Day 6
#  34          Day 2
#  35          Day 6
#  36          Day 1
#  37         Finals
#  38          Day 5
#  39  Quarterfinals
#  40          Day 4
#  41          Day 5
#  42          Day 5
#  43          Day 5
#  44          Day 3
#  45          Day 3
#  46          Day 8
#  47  Quarterfinals
#  48     Semifinals
#  49          Day 4
#  50          Day 1
#  51          Day 7
#  52          Day 4
#  53          Day 1
#  54          Day 8
#  55          Day 8  ,
#  2021:           Team1                  Team2 Team1Score Team2Score          Tab
#  0   100 Thieves     DetonatioN FocusMe          1          0        Day 2
#  1   100 Thieves     DetonatioN FocusMe          1          0        Day 5
#  2   100 Thieves          EDward Gaming          0          1        Day 1
#  3   100 Thieves          EDward Gaming          1          0        Day 5
#  4        Cloud9  Rogue (European Team)          1          0  Tiebreakers
#  ..          ...                    ...        ...        ...          ...
#  56  Team Liquid                  Gen.G          0          1  Tiebreakers
#  57  Team Liquid                  Gen.G          1          0        Day 7
#  58  Team Liquid            LNG Esports          0          1        Day 2
#  59  Team Liquid            LNG Esports          1          0        Day 7
#  60  Team Liquid              MAD Lions          1          0        Day 1
#
#  [61 rows x 5 columns],
#  2022:                     Team1                  Team2 Team1Score Team2Score  \
#  0             100 Thieves     CTBC Flying Oyster          1          0
#  1             100 Thieves                  Gen.G          0          1
#  2             100 Thieves    Royal Never Give Up          0          1
#  3                  Cloud9          EDward Gaming          0          1
#  4                  Cloud9                 Fnatic          0          1
#  5                  Cloud9                     T1          0          1
#  6      CTBC Flying Oyster            100 Thieves          1          0
#  7      CTBC Flying Oyster                  Gen.G          0          1
#  8      CTBC Flying Oyster    Royal Never Give Up          0          1
#  9                     DRX          EDward Gaming          3          2
#  10                    DRX            GAM Esports          1          0
#  11                    DRX  Rogue (European Team)          1          0
#  12                    DRX  Rogue (European Team)          1          0
#  13                    DRX            Top Esports          1          0
#  14                DWG KIA       Evil Geniuses.NA          1          0
#  15                DWG KIA             G2 Esports          1          0
#  16                DWG KIA              JD Gaming          0          1
#  17                DWG KIA              JD Gaming          0          1
#  18          EDward Gaming                 Cloud9          1          0
#  19          EDward Gaming                 Fnatic          1          0
#  20          EDward Gaming                     T1          0          1
#  21       Evil Geniuses.NA                DWG KIA          0          1
#  22       Evil Geniuses.NA             G2 Esports          0          1
#  23       Evil Geniuses.NA              JD Gaming          0          1
#  24                 Fnatic                 Cloud9          0          1
#  25                 Fnatic          EDward Gaming          0          1
#  26                 Fnatic                     T1          1          0
#  27             G2 Esports                DWG KIA          0          1
#  28             G2 Esports       Evil Geniuses.NA          0          1
#  29             G2 Esports              JD Gaming          0          1
#  30            GAM Esports                    DRX          0          1
#  31            GAM Esports  Rogue (European Team)          0          1
#  32            GAM Esports            Top Esports          1          0
#  33                  Gen.G            100 Thieves          1          0
#  34                  Gen.G     CTBC Flying Oyster          1          0
#  35                  Gen.G                    DRX          1          3
#  36                  Gen.G                DWG KIA          3          2
#  37                  Gen.G    Royal Never Give Up          0          1
#  38                  Gen.G    Royal Never Give Up          1          0
#  39              JD Gaming                DWG KIA          0          1
#  40              JD Gaming       Evil Geniuses.NA          1          0
#  41              JD Gaming             G2 Esports          1          0
#  42              JD Gaming  Rogue (European Team)          3          0
#  43              JD Gaming                     T1          1          3
#  44  Rogue (European Team)                    DRX          1          0
#  45  Rogue (European Team)            GAM Esports          1          0
#  46  Rogue (European Team)            Top Esports          1          0
#  47    Royal Never Give Up            100 Thieves          1          0
#  48    Royal Never Give Up     CTBC Flying Oyster          1          0
#  49    Royal Never Give Up                  Gen.G          0          1
#  50                     T1                 Cloud9          1          0
#  51                     T1                    DRX          2          3
#  52                     T1          EDward Gaming          1          0
#  53                     T1                 Fnatic          1          0
#  54                     T1    Royal Never Give Up          3          0
#  55            Top Esports                    DRX          1          0
#  56            Top Esports            GAM Esports          1          0
#  57            Top Esports  Rogue (European Team)          1          0
#
#                Tab
#  0           Day 8
#  1           Day 3
#  2           Day 4
#  3           Day 5
#  4           Day 1
#  5           Day 3
#  6           Day 1
#  7           Day 8
#  8           Day 8
#  9   Quarterfinals
#  10          Day 7
#  11          Day 7
#  12    Tiebreakers
#  13          Day 3
#  14          Day 4
#  15          Day 6
#  16          Day 2
#  17    Tiebreakers
#  18          Day 2
#  19          Day 3
#  20          Day 5
#  21          Day 6
#  22          Day 2
#  23          Day 6
#  24          Day 5
#  25          Day 5
#  26          Day 2
#  27          Day 1
#  28          Day 6
#  29          Day 6
#  30          Day 4
#  31          Day 3
#  32          Day 7
#  33          Day 8
#  34          Day 4
#  35     Semifinals
#  36  Quarterfinals
#  37          Day 1
#  38    Tiebreakers
#  39          Day 6
#  40          Day 1
#  41          Day 4
#  42  Quarterfinals
#  43     Semifinals
#  44          Day 2
#  45          Day 7
#  46          Day 4
#  47          Day 8
#  48          Day 3
#  49          Day 8
#  50          Day 5
#  51         Finals
#  52          Day 1
#  53          Day 5
#  54  Quarterfinals
#  55          Day 7
#  56          Day 2
#  57          Day 7  }

# %%
def WhoWon(row):
    if row["Team1Score"]>row["Team2Score"]: return row["Team1"]
    else: return row["Team2"]

# %%
df_KnockoutStage = dict() # Will contain the matches for the quarterfinals,semifinals and finals
for year in range(2017,2023):
    dict_groups_data[year]["Wins"] = 0
    df_KnockoutStage[year] = pd.DataFrame([], columns=dict_Worlds_data[year].columns)
    for index,row in dict_Worlds_data[year].iterrows():
        if (row.Tab not in ['Quarterfinals', 'Semifinals', 'Finals']):
            winner_row = dict_groups_data[year].Team == WhoWon(row)
            dict_groups_data[year].Wins[winner_row] += 1
        else:
            df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
    df_KnockoutStage[year]["Winner"] = df_KnockoutStage[year].apply(WhoWon,axis=1)
# Out:
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
# C:\Users\vivia\AppData\Local\Temp\ipykernel_8852\3970410261.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dict_groups_data[year].Wins[winner_row] += 1

# %%
df_KnockoutStage[2022]
# Out:
#         Team1                  Team2 Team1Score Team2Score            Tab  \
# 9         DRX          EDward Gaming          3          2  Quarterfinals
# 35      Gen.G                    DRX          1          3     Semifinals
# 36      Gen.G                DWG KIA          3          2  Quarterfinals
# 42  JD Gaming  Rogue (European Team)          3          0  Quarterfinals
# 43  JD Gaming                     T1          1          3     Semifinals
# 51         T1                    DRX          2          3         Finals
# 54         T1    Royal Never Give Up          3          0  Quarterfinals
#
#        Winner
# 9         DRX
# 35        DRX
# 36      Gen.G
# 42  JD Gaming
# 43         T1
# 51        DRX
# 54         T1

# %%
df_Worlds_Winners = dict() # Will contain the matches for the quarterfinals,semifinals and finals
for year in range(2015,2023):
    dict_groups_data[year]["Wins"] = 0
    df_KnockoutStage[year] = pd.DataFrame([], columns=dict_Worlds_data[year].columns)
    for index,row in dict_Worlds_data[year].iterrows():
        if (row.Tab not in ['Quarterfinals', 'Semifinals', 'Finals']):
            winner_row = dict_groups_data[year].Team == WhoWon(row)
            dict_groups_data[year].Wins[winner_row] += 1
        else:
            df_KnockoutStage[year] = df_KnockoutStage[year].append(row)
    df_KnockoutStage[year]["Winner"] = df_KnockoutStage[year].apply(WhoWon,axis=1)
